# %%
import xarray as xr
import metpy.calc as mpcalc
from metpy.units import units
import pandas as pd
import geopandas as gpd
import matplotlib as plt
from metpy.interpolate import interpolate_to_grid

# %%
#!pwd

# %%
path = '/home/jovyan/'
file = 'data_stream-oper_stepType-instant.nc'
#path+file

# %%
Sept2017_wind_data = xr.open_dataset(path+file)

# %%
Sept2017_wind_data
# Out:
# <xarray.Dataset> Size: 991kB
# Dimensions:     (valid_time: 720, latitude: 13, longitude: 13)
# Coordinates:
#     number      int64 8B ...
#   * valid_time  (valid_time) datetime64[ns] 6kB 2017-09-01 ... 2017-09-30T23:...
#   * latitude    (latitude) float64 104B 26.5 26.25 26.0 ... 24.0 23.75 23.5
#   * longitude   (longitude) float64 104B -82.7 -82.45 -82.2 ... -79.95 -79.7
#     expver      (valid_time) <U4 12kB ...
# Data variables:
#     u10         (valid_time, latitude, longitude) float32 487kB ...
#     v10         (valid_time, latitude, longitude) float32 487kB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-02-14T16:20 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
plt.figure(2, figsize=(10,10))
ax = plt.subplot(111)
