# %%
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /home/jovyan

# %%
path = '/home/jovyan/'
file = 'IAN_tmp.csv'

# %%
IAN_tmp = pd.read_csv(path + file)

# %%
#IAN_tmp

# %%
IAN_tmp['t'].plot()
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots()

ax.plot(IAN_tmp['t'], color = 'r')

ax.set_title('Temperature')

fig.savefig('IAN_tmp.png')

#Play around with a time series and using the col and col_wrap in the plots
