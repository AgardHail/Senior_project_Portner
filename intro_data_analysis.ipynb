# %% [markdown]
# # Step 1
#
# ## Import needed packages

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import xarray as xr
import matplotlib.pyplot as plt

# %%
np.max([1, 12, 2, 2, 1, 54])
# Out:
# 54

# %%
# !pwd
# Out:
# /home/jovyan

# %%
file = 'HurricaneIAN.nc'
path = '/home/jovyan/'

# %%
IAN_data = xr.open_dataset(path+file)
IAN_data
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:    (longitude: 61, latitude: 61, level: 27, time: 144)
# Coordinates:
#   * longitude  (longitude) float32 244B -90.0 -89.75 -89.5 ... -75.25 -75.0
#   * latitude   (latitude) float32 244B 35.0 34.75 34.5 34.25 ... 20.5 20.25 20.0
#   * level      (level) int32 108B 100 125 150 175 200 ... 900 925 950 975 1000
#   * time       (time) datetime64[ns] 1kB 2022-09-19 ... 2022-09-30T22:00:00
# Data variables: (12/16)
#     d          (time, level, latitude, longitude) float64 116MB ...
#     cc         (time, level, latitude, longitude) float64 116MB ...
#     z          (time, level, latitude, longitude) float64 116MB ...
#     o3         (time, level, latitude, longitude) float64 116MB ...
#     pv         (time, level, latitude, longitude) float64 116MB ...
#     r          (time, level, latitude, longitude) float64 116MB ...
#     ...         ...
#     cswc       (time, level, latitude, longitude) float64 116MB ...
# ...

# %%
IAN_data.t
# Out:
# <xarray.DataArray 't' (time: 144, level: 27, latitude: 61, longitude: 61)> Size: 116MB
# [14467248 values with dtype=float64]
# Coordinates:
#   * longitude  (longitude) float32 244B -90.0 -89.75 -89.5 ... -75.25 -75.0
#   * latitude   (latitude) float32 244B 35.0 34.75 34.5 34.25 ... 20.5 20.25 20.0
#   * level      (level) int32 108B 100 125 150 175 200 ... 900 925 950 975 1000
#   * time       (time) datetime64[ns] 1kB 2022-09-19 ... 2022-09-30T22:00:00
# Attributes:
#     units:          K
#     long_name:      Temperature
#     standard_name:  air_temperature

# %%
#IAN_data['t'].values

# %%
IAN_data['t'].to_dataframe().to_csv('Hurricane IAN')

# %%
IAN_data['t'].isel(time = 0, level = 0)
# Out:
# <xarray.DataArray 't' (latitude: 61, longitude: 61)> Size: 30kB
# [3721 values with dtype=float64]
# Coordinates:
#   * longitude  (longitude) float32 244B -90.0 -89.75 -89.5 ... -75.25 -75.0
#   * latitude   (latitude) float32 244B 35.0 34.75 34.5 34.25 ... 20.5 20.25 20.0
#     level      int32 4B 100
#     time       datetime64[ns] 8B 2022-09-19
# Attributes:
#     units:          K
#     long_name:      Temperature
#     standard_name:  air_temperature

# %%
IAN_table = IAN_data['t'].isel(time = 0).to_dataframe() #Temperature to table

# %%
#IAN_table

# %%
IAN_table.to_csv('IAN_tmp.csv') #save as CSV. May need to rename to have .csv in it
